# %%
from TelopsToolbox.hcc.readIRCam import read_ircam
import TelopsToolbox.utils.image_processing as ip
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from IR_calc import IR_calculation
import pandas as pd
from plotly.subplots import make_subplots
import numpy as np
from comparison import compare_all_exp
import os

# %%
experiment_path = 'C:/Users/dflws/Desktop/test/BC_SR2/Exp #1/'
IR_path = 'C:/Users/dflws/Desktop/test/IR_test/Specimen1_IR.hcc'

# %%
exp_data = pd.read_csv(experiment_path+'Stress-Strain True.csv')
exp_time = pd.read_csv(experiment_path+'Forces.csv')[' time [s]']
sample_rate = 2e6

# %%
time = np.arange(0,(len(exp_data)-1)/sample_rate, 1/sample_rate)
stress = np.array(exp_data[' Stress']) 
strain = np.array(exp_data['# Strain'])

# %%
IR_calculation(IR_path, stress, strain, time)
# Out:
# True

# %%
fig1 = make_subplots(specs=[[{"secondary_y": True}]])
fig1.update_layout(template = 'plotly_white', width=800, height=600,
                  title = 'Comparison Strain vs Temperature')
fig1.add_trace(go.Scatter(x = time, 
                            y = strain,
                            name = 'True Strain'),
                            secondary_y=False)
fig1.add_trace(go.Scatter(x = time, 
                            y = stress,
                            name = 'True Stress'),
                            secondary_y=False)
fig1.add_trace(go.Scatter(x = ir_time, 
                            y = temperature, 
                            name = 'Temperature'),
                            secondary_y=True)

fig1.update_xaxes(title_text="Time, s")

fig1.update_yaxes(title_text="Strain", secondary_y=False)
fig1.update_yaxes(title_text="Temperature", secondary_y=True)

fig1
fig1.show()

# %%
material = 'Material'
specimen = 'Specimen'
fig2 = make_subplots(specs=[[{"secondary_y": True}]])
fig2.update_layout(template = 'plotly_white', width=800, height=600,
                  title = f'True Strain vs Temperature, {material} specimen {specimen}')
fig2.add_trace(go.Scatter(x = strain, 
                            y = stress,
                            name = 'True Stress'),
                            secondary_y=False)
fig2.add_trace(go.Scatter(x = eq_strain, 
                            y = temperature, 
                            name = 'Temperature'),
                            secondary_y=True)

fig2.update_xaxes(title_text="Strain")

fig2.update_yaxes(title_text="Stress, MPa", secondary_y=False)
fig2.update_yaxes(title_text="Temperature, C", secondary_y=True)

fig2
fig2.show()

# %%
path = 'C:/Users/dflws/Desktop/test/BC_SR2/'
dir = os.listdir(path)
exp = [item for item in dir if '#' in item.split()[-1]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [12], line 3
#       1 path = 'C:/Users/dflws/Desktop/test/BC_SR2/'
#       2 dir = os.listdir(path)
# ----> 3 exp = [item for item in dir if '#' in item.split()[1]]
#
# Cell In [12], line 3, in <listcomp>(.0)
#       1 path = 'C:/Users/dflws/Desktop/test/BC_SR2/'
#       2 dir = os.listdir(path)
# ----> 3 exp = [item for item in dir if '#' in item.split()[1]]
#
# IndexError: list index out of range

# %%
dir
# Out:
# ['all_exp_mech.html',
#  'Exp #1',
#  'Exp #2',
#  'Exp 1.html',
#  'Exp 2.html',
#  'Original WFT Files']

# %%
def add_data_to_report(data, title):
    trace_mech = go.Scatter(x = data['# Strain'], y = data[' Stress'], name = f'{title} ')
    return trace_mech

# %%
exp_path = path + '/' + exp[0] + '/'
exp_path
# Out:
# 'C:/Users/dflws/Desktop/test/BC_SR2//Exp #1/'

# %%
exp_data = pd.read_csv(exp_path+'Stress-Strain True.csv')

# %%
exp_data.columns
# Out:
# Index(['# Strain', ' Stress'], dtype='object')

# %%
# def print_report(material):
fig1 = go.Figure()
fig1.update_layout(template = 'none', 
                    font=dict(size=16),
                    title = f'Stress-Strain curves for {exp[0]}')
fig1.update_xaxes(title = 'Strain')
fig1.update_yaxes(title = 'Stress, [MPa]')
result = []

for item in exp:
    exp_path = path + '/' + item + '/'
    exp_data = pd.read_csv(exp_path+'Stress-Strain True.csv')
    parameters = pd.read_csv(exp_path+'Parameters.txt', sep = ' ', header = None)
    fig1.add_trace(add_data_to_report(exp_data, item))

    result.append(pd.DataFrame({'specimen': item,
                        'diameter[m]': parameters.iloc[0][2],
                        'length[m]': parameters.iloc[1][2],
                        'Ult_Stress': exp_data[' Stress'].max(),
                        'Strain4Ult_Stress': exp_data['# Strain'][exp_data[' Stress'].idxmax()]}, index = [item[-1]]))
fin_table = pd.concat(result)

# %%
fig1.show()

# %%
fin_table
# Out:
#   specimen diameter[m] length[m]  Ult_Stress  Strain4Ult_Stress
# 1   Exp #1      0.0083    0.0082  175.870961           0.041559
# 2   Exp #2      0.0083    0.0082  129.266291           0.029545

# %%
# exp_data[' Stress'].max()
exp_data['# Strain'][exp_data[' Stress'].idxmax()]
# Out:
# 0.0295448856316594

# %%
result = pd.DataFrame({'specimen': exp[0],
                        'diameter[m]': parameters.iloc[0][2],
                        'length[m]': parameters.iloc[1][2],
                        'Ult_Stress': exp_data[' Stress'].max(),
                        'Strain4Ult_Stress': exp_data['# Strain'][exp_data[' Stress'].idxmax()]}, index = ['0'])

# %%
result
# Out:
#   specimen diameter[m] length[m]  Ult_Stress  Strain4Ult_Stress
# 0   Exp #1      0.0083    0.0082  129.266291           0.029545

# %%
fig, table = compare_all_exp(path = 'C:/Users/dflws/Desktop/test/BC_SR2/')

# %%
exp[0].split('#')
# Out:
# ['Exp ', '1']

# %%
dir = os.listdir(path)
exp = [item for item in dir if '#' in item.split()[1]]
# Out:
# '1'

# %%
os.system('pip3 list')
# Out:
# 0
